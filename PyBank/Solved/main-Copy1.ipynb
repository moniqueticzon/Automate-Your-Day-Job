# %%
from pathlib import Path
import csv

csvpath = Path('../Resource_Data/budget_data.csv')

analysis = []

with open(csvpath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    csv_header = next(csvreader)
    print(csv_header)
    
    csv_header.append("Profit/Losses_2")
    csv_header.append("Change")
    
    analysis.append(csv_header)
    
    for row in csvreader:
        print(row)

        date = row[0]
        profit = int(row[1])      
        
        profit2 = profit
        change = profit2 - profit
                
        row.append(profit2)
        row.append(change)
        
        analysis.append(row)

output = Path("output.csv")

with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')

    for record in analysis:
        csvwriter.writerow(record)
# Out:
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ['Dec-2012', '542494']
# ['Jan-2013', '359333']
# ['Feb-2013', '321469']
# ...

# %%
print(analysis)
# Out:
# [['Date', 'Profit/Losses', 'Profit/Losses_2', 'Change'], ['Jan-2010', '867884', 867884, 0], ['Feb-2010', '984655', 984655, 0], ['Mar-2010', '322013', 322013, 0], ['Apr-2010', '-69417', -69417, 0], ['May-2010', '310503', 310503, 0], ['Jun-2010', '522857', 522857, 0], ['Jul-2010', '1033096', 1033096, 0], ['Aug-2010', '604885', 604885, 0], ['Sep-2010', '-216386', -216386, 0], ['Oct-2010', '477532', 477532, 0], ['Nov-2010', '893810', 893810, 0], ['Dec-2010', '-80353', -80353, 0], ['Jan-2011', '779806', 779806, 0], ['Feb-2011', '-335203', -335203, 0], ['Mar-2011', '697845', 697845, 0], ['Apr-2011', '793163', 793163, 0], ['May-2011', '485070', 485070, 0], ['Jun-2011', '584122', 584122, 0], ['Jul-2011', '62729', 62729, 0], ['Aug-2011', '668179', 668179, 0], ['Sep-2011', '899906', 899906, 0], ['Oct-2011', '834719', 834719, 0], ['Nov-2011', '132003', 132003, 0], ['Dec-2011', '309978', 309978, 0], ['Jan-2012', '-755566', -755566, 0], ['Feb-2012', '1170593', 1170593, 0], ['Mar-2012', '252788', 
# ...

# %%
month_count = len(analysis) - 1
total_money = 0
average_change = 0
greatest_increase = 0
greatest_decrease = 0

# %%
print("Financial Analysis")
print("-------------------------------")
print(f"Total months: {month_count}")
print(f"Total profit: ${total_money}")
print(f"Average Change: ${average_change}")
print(f"Greatest Increase in Profits: ${greatest_increase}")
print(f"Greate Decrease in Profits: ${greatest_decrease}")
# Out:
# Financial Analysis
# -------------------------------
# Total months: 86
# Total profit: $0
# Average Change: $0
# Greatest Increase in Profits: $0
# Greate Decrease in Profits: $0
